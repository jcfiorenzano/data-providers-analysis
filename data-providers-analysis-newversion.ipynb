# %%
# Load the data
import pandas as pd
import json
import matplotlib.pyplot as plt

# Reading the data
data_frame_db1 = pd.DataFrame(pd.read_csv("./data/20230222-alert-data/alert-data-db1.csv"))
data_frame_db2 = pd.DataFrame(pd.read_csv("./data/20230222-alert-data/alert-data-db2.csv"))
data_frame_db3 = pd.DataFrame(pd.read_csv("./data/20230222-alert-data/alert-data-db3.csv"))

# Creating main dataframe
data_frame = pd.concat([data_frame_db1, data_frame_db2, data_frame_db3], sort=False)
data_frame = data_frame.drop_duplicates(subset=['AlertKey'], keep='first')
data_frame.reset_index()

# Deconstructing the sources data
# to create one source per row
sources_df = pd.DataFrame({'AlertKey':[],
                           'Source': [],
                           'Url':[]})

for index, row in data_frame.iterrows():
    json_sources = row['Sources']
    sources = json.loads(json_sources)
    for key in sources.keys():
        # Dropping entries for TWC
        if key != "TwC":
            sources_df = pd.concat([sources_df, pd.DataFrame({'AlertKey': row['AlertKey'], 'Source': key, 'Url': sources[key]})])

data_frame = data_frame.merge(sources_df, left_on='AlertKey', right_on='AlertKey')
data_frame.drop('Sources', axis=1, inplace=True)

# Adding component type information
component_type_data = [[1, "NuGet"], [2, "Npm"], [3, "Maven"], [4, "Git"], [6, "RubyGems"], [7, "Cargo"], [8, "Pip"], [9, "File"], [10, "Go"], [12, "Pod"], [13, "Linux"], [14, "Conda"]]
component_typesDf = pd.DataFrame(data=component_type_data, columns=["ComponentTypeId", "ComponentType"])
data_frame = data_frame.merge(right=component_typesDf, left_on="ComponentType", right_on="ComponentTypeId", how="left")
data_frame.drop('ComponentTypeId', axis=1, inplace=True)
data_frame.drop('ComponentType_x', axis=1, inplace=True)
data_frame.rename(columns={'ComponentType_y': 'ComponentType'}, inplace=True)

# Adding severity information
severity_data = [[0, "Low"], [1, "Medium"], [2, "High"], [3, "Critical"]]
severities = pd.DataFrame(data=severity_data, columns=["SeverityId", "Severity"])
data_frame = data_frame.merge(right=severities, left_on="Severity", right_on="SeverityId", how="left")
data_frame.drop('SeverityId', axis=1, inplace=True)
data_frame.drop('Severity_x', axis=1, inplace=True)
data_frame.rename(columns={'Severity_y': 'Severity'}, inplace=True)

# Filtering Data
last_year_data = data_frame[data_frame["DiscoveryDate"] > "2021-12-31"]

# %%
# Alerts distribution by data providers

last_year_data.groupby('Source')['AlertKey'] \
    .count() \
    .plot(kind='pie', textprops={'fontsize':15, 'color':'white'}, figsize=(10,10), autopct='%1.2f%%', legend=True)

plt.show()

# %%
# Alerts distribution by data providers excluding ComponentType File
last_year_data[last_year_data['ComponentType'] != "File"].groupby('Source')['AlertKey']\
    .count()\
    .plot(kind='pie', textprops={'fontsize':15, 'color':'white'}, figsize=(10,10), autopct='%1.2f%%', legend=True)

plt.show()

# %%
# Percentage of alerts that are only found in GA
ga_alerts = last_year_data[last_year_data['Source'] == 'GitHubAdvisories']
no_ga_alerts = last_year_data[last_year_data['Source'] != 'GitHubAdvisories']
# some alerts are found in multiple sources, doing this we guarantee that we are going to get
# only the alerts that have only one source and that source is GithubAdvisories
only_ga = ga_alerts[~ga_alerts['AlertKey'].isin(no_ga_alerts['AlertKey'])]
(only_ga.shape[0]/data_frame.shape[0])*100
# Out:
# 5.779678649867067

# %%
# Distribution of vulnerabilities ids from alerts found only by GA

ghsa = only_ga.Title.str.startswith('GHSA', na=False).sum()
cve = only_ga.Title.str.startswith('CVE', na=False).sum()
other = only_ga.shape[0] - ghsa - cve

plt.pie([ghsa, cve, other], labels=["GHSA", "CVE", "Other"], textprops={'color':"white", 'fontsize':12}, autopct='%1.2f%%')
plt.show()

# %%
# Distribution of vulnerabilities ids for alerts that were only found by WS
ws_alerts = last_year_data[last_year_data['Source'] == 'WhiteSource']
no_ws_alerts = last_year_data[last_year_data['Source'] != 'WhiteSource']
only_ws = ws_alerts[~ws_alerts['AlertKey'].isin(no_ws_alerts['AlertKey'])]

ws = only_ws.Title.str.startswith('WS', na=False).sum()
cve = only_ws.Title.str.startswith('CVE', na=False).sum()
other = only_ws.shape[0] - ws - cve

plt.pie([ws, cve, other], labels=["WS", "CVE", "Other"], textprops={'color':"white", 'fontsize':12}, autopct='%1.2f%%')
plt.show()

# %%
# Component types of the CVE alerts that where only found by WS

ws_cve_alerts = only_ws[only_ws.Title.str.startswith('CVE', na=False)]
ws_cve_alerts.groupby('ComponentType')['AlertKey'].count().plot(kind='pie', textprops={'fontsize':15, 'color':'white'}, figsize=(10,10),autopct='%1.2f%%', legend=True)
# Out:
# <AxesSubplot: ylabel='AlertKey'>

# %%
# Severity distribution of alerts of type File
data_frame[data_frame["ComponentType"] == "File"].groupby("Severity")["AlertKey"].count().plot(kind='pie', textprops={'fontsize':15, 'color':'white'}, figsize=(10,10),autopct='%1.2f%%', legend=True)
# Out:
# <AxesSubplot: ylabel='AlertKey'>

# %%
# percentage of whitesource alerts that are also found in github advisories for common component types.
ws_common = ws_alerts[(ws_alerts["ComponentType"] == "Npm") | (ws_alerts["ComponentType"] == "RubyGems") | (ws_alerts["ComponentType"] == "Maven") | (ws_alerts["ComponentType"] == "NuGet")]
ws_alerts_covered_by_ga = ga_alerts[ga_alerts["AlertKey"].isin(ws_common['AlertKey'])]
(ws_alerts_covered_by_ga.shape[0]/ws_common.shape[0]) * 100
# Out:
# 56.68523676880223

# %%
# Distribution of alerts only found by WS by
common_type_ws_only_alerts = ws_common[(~(ws_common["AlertKey"].isin(ws_alerts_covered_by_ga['AlertKey']))) & (~(ws_common["Title"].str.startswith('WS', na=False)))]
common_type_ws_only_alerts .groupby("ComponentType")["AlertKey"].count().plot(kind="pie", autopct='%1.2f%%')
# Out:
# <AxesSubplot: ylabel='AlertKey'>

# %%
common_type_ws_only_alerts[common_type_ws_only_alerts["ComponentType"] == "Maven"]
# Out:
#       PartitionId  DataspaceId  RepositoryId  AlertId  \
# 56             10         1814        154950  7476542
# 178            10         2133        185250  6802034
# 186            10         1814          3233  6841068
# 201            10         1814        104410  7351077
# 492            10         2133        198059  7533848
# ...           ...          ...           ...      ...
# 8604            3       167420        193662  6809247
# 8605            3       167420        193662  6809249
# 8606            3       167420        193662  6809241
# 8607            3       167420        193662  6809242
# 8608            3       167420        193662  6809246
#
#                                             Description           Title  \
# 56    JacksonJsonpInterceptor in RESTEasy might allo...   CVE-2016-6348
# 178   By default, Apache CXF creates a /services pag...  CVE-2019-17573
# 186   randomUUID in Scala.js before 1.10.0 generates...  CVE-2022-28355
# 201   A mis-handling of invalid unicode characters i...   CVE-2020-8929
# 492   A vulnerability in Apache Flink (1.1.0 to 1.1....   CVE-2020-1960
# ...                                                 ...             ...
# 8604  TensorFlow is an end-to-end open source platfo...  CVE-2021-37688
# 8605  TensorFlow is an end-to-end open source platfo...  CVE-2021-37681
# 8606  TensorFlow is an end-to-end open source platfo...  CVE-2021-37682
# 8607  TensorFlow is an end-to-end open source platfo...  CVE-2021-37687
# 8608  TensorFlow is an end-to-end open source platfo...  CVE-2021-37689
#
#                                  AlertKey                DiscoveryDate  \
# 56    v6:499f6f3a077e44a7aee44ed69d3ba637  2022-07-22 00:14:25.3276444
# 178   v6:86ec0a83cdad450ba825758305851be6  2022-03-21 10:23:28.4417115
# 186   v6:75379330e7ea4e4a9f2bd6bff5d64ce6  2022-04-04 20:23:02.2537533
# 201   v6:4365ce980e8749d08015002d39201d90  2022-06-27 08:22:54.9749161
# 492   v6:834dcaaafe0d4de9b2a3fe04debe1e3c  2022-08-03 12:52:43.6632759
# ...                                   ...                          ...
# 8604  v6:bca607f7a9184d9d830d9c0e921d56df  2022-03-23 21:09:57.0369425
# 8605  v6:ed3d863a8449441cae17803f32594685  2022-03-23 21:09:57.0369425
# 8606  v6:0463e1c29a01467580e0135ea6482470  2022-03-23 21:09:57.0369425
# 8607  v6:3470d2d9cc31459f811943a4c079ed35  2022-03-23 21:09:57.0369425
# 8608  v6:a9cf384b2d7147ed9d13e83283bc6566  2022-03-23 21:09:57.0369425
#
#            Source                                                Url  \
# 56    WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 178   WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 186   WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 201   WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 492   WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# ...           ...                                                ...
# 8604  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 8605  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 8606  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 8607  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 8608  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
#
#      ComponentType Severity
# 56           Maven   Medium
# 178          Maven   Medium
# 186          Maven   Medium
# 201          Maven   Medium
# 492          Maven      Low
# ...            ...      ...
# 8604         Maven      Low
# 8605         Maven   Medium
# 8606         Maven      Low
# 8607         Maven      Low
# 8608         Maven      Low
#
# [162 rows x 12 columns]

# %%
common_type_ws_only_alerts[common_type_ws_only_alerts["ComponentType"] == "Maven"].groupby("Severity")["AlertKey"].count().plot(kind="pie", autopct='%1.2f%%')
# Out:
# <AxesSubplot: ylabel='AlertKey'>

# %%
common_type_ws_only_alerts[common_type_ws_only_alerts["ComponentType"] == "Npm"]
# Out:
#       PartitionId  DataspaceId  RepositoryId  AlertId  \
# 42             10         1814        106763  6694405
# 2506          220         6325        120703  8096127
# 2575          205        34348        154455  8258949
# 2739          430         7052         89016  7202661
# 2973          933         8510        195434  7350853
# 3376         2767        50640        178193  7410482
# 3522         3019       159651        189358  8352888
# 3671         3344       139174        160777  7892656
# 5696        36366       141891        182977  7193102
# 5718        36366       136532        162693  6752698
# 5851        36366       136532        162693  7532229
# 5852        36366       136532        162693  7145153
# 6348        39580       289569        209369  7696634
# 6463        40833       298629        202268  7262572
# 6471        41386       307033        204223  7557369
# 6472        41572       308138        203684  7327192
# 6487        41572       308138        203684  7327122
# 8402            3       152426        177144  6879825
# 8540            3       159106        184651  7704436
#
#                                             Description           Title  \
# 42    jQuery Cookie 1.4.1 is affected by prototype p...  CVE-2022-23395
# 2506  The package snyk before 1.1064.0 are vulnerabl...  CVE-2022-24441
# 2575  All versions of the package create-choo-electr...  CVE-2022-25908
# 2739  An arbitrary file upload vulnerability in the ...  CVE-2022-29623
# 2973  A Regular Expression Denial of Service (ReDOS)...  CVE-2021-40892
# 3376  Underscore.deep is a collection of Underscore ...  CVE-2022-31106
# 3522  ** DISPUTED ** CKSource CKEditor 5 35.4.0 was ...  CVE-2022-48110
# 3671  Prototype pollution vulnerability in beautify-...  CVE-2022-37609
# 5696  OpenZeppelin Contracts is a library for smart ...  CVE-2022-31172
# 5718  This affects the package node-ipc from 10.1.1 ...  CVE-2022-23812
# 5851  Insufficient policy enforcement in DevTools in...   CVE-2022-4187
# 5852  Inappropriate implementation in DevTools in Go...  CVE-2021-21137
# 6348  ** DISPUTED ** The npm ci command in npm 7.x a...  CVE-2021-43616
# 6463  Prototype pollution vulnerability in 'shvl' ve...  CVE-2020-28278
# 6471  pdfmake is an open source client/server side P...  CVE-2022-46161
# 6472  The normalize-url package before 4.5.1, 5.x be...  CVE-2021-33502
# 6487  The css-what package 4.0.0 through 5.0.0 for N...  CVE-2021-33587
# 8402  An arbitrary file upload vulnerability in the ...  CVE-2022-27140
# 8540  The package protobufjs before 6.11.3 are vulne...  CVE-2022-25878
#
#                                  AlertKey                DiscoveryDate  \
# 42    v6:63c60f7d750b43188b2ddcd6070b8cc4  2022-03-03 22:17:15.2251341
# 2506  v6:dcfb0c79d2a5401b92af3b5840971117  2022-12-02 10:22:33.0590284
# 2575  v6:9192c8375c094a46bd58c7ffd66c86dc  2023-01-27 20:31:05.0428269
# 2739  v6:cd045fb1b7e04cae9d70fa4a788ac441  2022-05-17 20:39:33.9418167
# 2973  v6:a762755cbb5b4217a15d6c74f44f05c6  2022-06-27 07:21:11.8559827
# 3376  v6:4e5dfc6d28a04e329b10c3afc982c1ff  2022-07-01 07:30:46.0224729
# 3522  v6:cbf058f1d427411790634181c59eb192  2023-02-21 05:14:15.6199776
# 3671  v6:5d44c13cb1784cd999d31bc8e4fa5adc  2022-10-28 19:49:27.9371124
# 5696  v6:7ea84b5b4dec443cb70fb2e5f9b4cd61  2022-07-22 19:44:48.3491440
# 5718  v6:ff8802ce13184ad4ab8b73eaaba1b4f8  2022-03-17 16:12:55.8030365
# 5851  v6:86742060d6b340d4ba94997bc896097a  2022-11-30 20:20:49.8241744
# 5852  v6:fff8cbbd5968486ca187b9bbe23600ee  2022-06-29 12:10:17.5933195
# 6348  v6:986f0a771229420aade9e1b44b7b8eca  2023-02-20 15:52:44.4176859
# 6463  v6:52b17fd22eab4d898d9e4d8180063b36  2022-09-12 08:26:24.1332584
# 6471  v6:dc0bf7e79de6489cbdbf0314a0573014  2022-12-09 15:05:24.4083358
# 6472  v6:6fd81324c1644386896b5914e7c52841  2022-10-09 18:10:57.5716781
# 6487  v6:5243e80b0f3f4be3bd31c13bba1893dd  2022-10-09 18:10:57.5716781
# 8402  v6:eea1309dab3744be9647d9bdad47b6e8  2022-04-14 03:06:46.8675169
# 8540  v6:c5c9c5157877402ca144d63f259ec25d  2022-09-30 02:03:47.8015454
#
#            Source                                                Url  \
# 42    WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 2506  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 2575  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 2739  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 2973  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 3376  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 3522  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 3671  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 5696  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 5718  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 5851  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 5852  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 6348  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 6463  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 6471  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 6472  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 6487  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 8402  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
# 8540  WhiteSource  https://vuln.whitesourcesoftware.com/vulnerabi...
#
#      ComponentType  Severity
# 42             Npm    Medium
# 2506           Npm      High
# 2575           Npm  Critical
# 2739           Npm    Medium
# 2973           Npm    Medium
# 3376           Npm      High
# 3522           Npm    Medium
# 3671           Npm  Critical
# 5696           Npm      High
# 5718           Npm  Critical
# 5851           Npm    Medium
# 5852           Npm    Medium
# 6348           Npm      High
# 6463           Npm      High
# 6471           Npm  Critical
# 6472           Npm    Medium
# 6487           Npm    Medium
# 8402           Npm      High
# 8540           Npm    Medium
